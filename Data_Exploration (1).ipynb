# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/ibtes/Downloads/players.csv") #importing the data

# %%
df.head()
# Out:
#    Unnamed: 0            Name        Position  Age  \
# 0           0   Kylian Mbappé  Centre-Forward   22
# 1           1  Erling Haaland  Centre-Forward   21
# 2           2      Harry Kane  Centre-Forward   28
# 3           3   Jack Grealish     Left Winger   26
# 4           4   Mohamed Salah    Right Winger   29
#
#    Markey Value In Millions(£)  Country                 Club  Matches  Goals  \
# 0                        144.0   France  Paris Saint-Germain       16      7
# 1                        135.0   Norway    Borussia Dortmund       10     13
# 2                        108.0  England    Tottenham Hotspur       16      7
# 3                         90.0  England      Manchester City       15      2
# 4                         90.0    Egypt         Liverpool FC       15     15
#
#    Own Goals  Assists  Yellow Cards  Second Yellow Cards  Red Cards  \
# 0          0       11             3                    0          0
# ...

# %%
pd.set_option('display.max_columns', None) # to display maximum/all columns

# %%
df.head() #None means all value if we need to show only 1 or 2 column then weneed to mention accordingly
# Out:
#    Unnamed: 0            Name        Position  Age  \
# 0           0   Kylian Mbappé  Centre-Forward   22
# 1           1  Erling Haaland  Centre-Forward   21
# 2           2      Harry Kane  Centre-Forward   28
# 3           3   Jack Grealish     Left Winger   26
# 4           4   Mohamed Salah    Right Winger   29
#
#    Markey Value In Millions(£)  Country                 Club  Matches  Goals  \
# 0                        144.0   France  Paris Saint-Germain       16      7
# 1                        135.0   Norway    Borussia Dortmund       10     13
# 2                        108.0  England    Tottenham Hotspur       16      7
# 3                         90.0  England      Manchester City       15      2
# 4                         90.0    Egypt         Liverpool FC       15     15
#
#    Own Goals  Assists  Yellow Cards  Second Yellow Cards  Red Cards  \
# 0          0       11             3                    0          0
# ...

# %%
df.columns #To see what are the columns available in your data
# Out:
# Index(['Unnamed: 0', 'Name', 'Position', 'Age', 'Markey Value In Millions(£)',
#        'Country', 'Club', 'Matches', 'Goals', 'Own Goals', 'Assists',
#        'Yellow Cards', 'Second Yellow Cards', 'Red Cards',
#        'Number Of Substitute In', 'Number Of Substitute Out'],
#       dtype='object')

# %%
df.dtypes #Lets check the data types of all the columns
# Out:
# Unnamed: 0                       int64
# Name                            object
# Position                        object
# Age                              int64
# Markey Value In Millions(£)    float64
# Country                         object
# Club                            object
# Matches                          int64
# Goals                            int64
# Own Goals                        int64
# Assists                          int64
# Yellow Cards                     int64
# Second Yellow Cards              int64
# Red Cards                        int64
# Number Of Substitute In          int64
# Number Of Substitute Out         int64
# dtype: object

# %%
#lets get the numerical columns only
df.select_dtypes(include=np.number)
# Out:
#      Unnamed: 0  Age  Markey Value In Millions(£)  Matches  Goals  Own Goals  \
# 0             0   22                        144.0       16      7          0
# 1             1   21                        135.0       10     13          0
# 2             2   28                        108.0       16      7          0
# 3             3   26                         90.0       15      2          0
# 4             4   29                         90.0       15     15          0
# ..          ...  ...                          ...      ...    ...        ...
# 495         495   27                         16.2        0      0          0
# 496         496   28                         16.2        8      1          0
# 497         497   24                         16.2        5      0          0
# 498         498   25                         16.2        8      0          0
# 499         499   27                         16.2       15      3          0
#
# ...

# %%
df.select_dtypes(include=np.number).columns #to see which are the columns having numeric values only
# Out:
# Index(['Unnamed: 0', 'Age', 'Markey Value In Millions(£)', 'Matches', 'Goals',
#        'Own Goals', 'Assists', 'Yellow Cards', 'Second Yellow Cards',
#        'Red Cards', 'Number Of Substitute In', 'Number Of Substitute Out'],
#       dtype='object')

# %%
##lets get the categorical columns only
df.select_dtypes(exclude=np.number)
# Out:
#                        Name            Position  Country  \
# 0             Kylian Mbappé      Centre-Forward   France
# 1            Erling Haaland      Centre-Forward   Norway
# 2                Harry Kane      Centre-Forward  England
# 3             Jack Grealish         Left Winger  England
# 4             Mohamed Salah        Right Winger    Egypt
# ..                      ...                 ...      ...
# 495  Giorgian de Arrascaeta  Attacking Midfield  Uruguay
# 496             Ayoze Pérez      Second Striker    Spain
# 497              Alex Meret          Goalkeeper    Italy
# 498         Duje Caleta-Car         Centre-Back  Croatia
# 499         Aritz Elustondo         Centre-Back    Spain
#
#                              Club
# 0             Paris Saint-Germain
# 1               Borussia Dortmund
# 2               Tottenham Hotspur
# 3                 Manchester City
# 4                    Liverpool FC
# ..                            ...
# ...

# %%
df.select_dtypes(exclude=np.number).columns #to see which are the columns having categorical values only
# Out:
# Index(['Name', 'Position', 'Country', 'Club'], dtype='object')

# %%
df.shape # to see how many rowa and columns are there in the Data
# Out:
# (500, 16)

# %%
#Let see the info of the dataset.
df.info() #column namse, number of non-null rows in each column, data type of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   500 non-null    int64
#  1   Name                         500 non-null    object
#  2   Position                     500 non-null    object
#  3   Age                          500 non-null    int64
#  4   Markey Value In Millions(£)  500 non-null    float64
#  5   Country                      500 non-null    object
#  6   Club                         500 non-null    object
#  7   Matches                      500 non-null    int64
#  8   Goals                        500 non-null    int64
#  9   Own Goals                    500 non-null    int64
#  10  Assists                      500 non-null    int64
#  11  Yellow Cards                 500 non-null    int64
#  12  Second Yellow Cards          500 non-null    int64
# ...

# %%
#lets display the important statistics of the dataset(numerical columns)
df.describe()
# Out:
#        Unnamed: 0         Age  Markey Value In Millions(£)     Matches  \
# count  500.000000  500.000000                   500.000000  500.000000
# mean   249.500000   24.968000                    31.537800   12.396000
# std    144.481833    3.165916                    17.577697    4.342453
# min      0.000000   16.000000                    16.200000    0.000000
# 25%    124.750000   23.000000                    19.800000   10.000000
# 50%    249.500000   25.000000                    25.200000   13.000000
# 75%    374.250000   27.000000                    36.000000   16.000000
# max    499.000000   36.000000                   144.000000   24.000000
#
#             Goals   Own Goals    Assists  Yellow Cards  Second Yellow Cards  \
# count  500.000000  500.000000  500.00000    500.000000           500.000000
# mean     2.160000    0.030000    1.51200      1.592000             0.036000
# std      2.880102    0.170758    1.85276      1.445585             0.186477
# ...

# %%
df.isnull().sum() # to check null values
# Out:
# Unnamed: 0                     0
# Name                           0
# Position                       0
# Age                            0
# Markey Value In Millions(£)    0
# Country                        0
# Club                           0
# Matches                        0
# Goals                          0
# Own Goals                      0
# Assists                        0
# Yellow Cards                   0
# Second Yellow Cards            0
# Red Cards                      0
# Number Of Substitute In        0
# Number Of Substitute Out       0
# dtype: int64

# %%
df[df['Matches'].isna()] # checking the null value of a particular column
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Position, Age, Markey Value In Millions(£), Country, Club, Matches, Goals, Own Goals, Assists, Yellow Cards, Second Yellow Cards, Red Cards, Number Of Substitute In, Number Of Substitute Out]
# Index: []

# %%
# let see the distribution of datapoints in each numerical column
df.hist(bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Markey Value In Millions(£)'}>],
#        [<AxesSubplot:title={'center':'Matches'}>,
#         <AxesSubplot:title={'center':'Goals'}>,
#         <AxesSubplot:title={'center':'Own Goals'}>],
#        [<AxesSubplot:title={'center':'Assists'}>,
#         <AxesSubplot:title={'center':'Yellow Cards'}>,
#         <AxesSubplot:title={'center':'Second Yellow Cards'}>],
#        [<AxesSubplot:title={'center':'Red Cards'}>,
#         <AxesSubplot:title={'center':'Number Of Substitute In'}>,
#         <AxesSubplot:title={'center':'Number Of Substitute Out'}>]],
#       dtype=object)

# %%
df.hist(bins=60, figsize=(15,20)) # same as above but aligning the figur size
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Markey Value In Millions(£)'}>],
#        [<AxesSubplot:title={'center':'Matches'}>,
#         <AxesSubplot:title={'center':'Goals'}>,
#         <AxesSubplot:title={'center':'Own Goals'}>],
#        [<AxesSubplot:title={'center':'Assists'}>,
#         <AxesSubplot:title={'center':'Yellow Cards'}>,
#         <AxesSubplot:title={'center':'Second Yellow Cards'}>],
#        [<AxesSubplot:title={'center':'Red Cards'}>,
#         <AxesSubplot:title={'center':'Number Of Substitute In'}>,
#         <AxesSubplot:title={'center':'Number Of Substitute Out'}>]],
#       dtype=object)

# %%
df.head() #againg checking the headings
# Out:
#    Unnamed: 0            Name        Position  Age  \
# 0           0   Kylian Mbappé  Centre-Forward   22
# 1           1  Erling Haaland  Centre-Forward   21
# 2           2      Harry Kane  Centre-Forward   28
# 3           3   Jack Grealish     Left Winger   26
# 4           4   Mohamed Salah    Right Winger   29
#
#    Markey Value In Millions(£)  Country                 Club  Matches  Goals  \
# 0                        144.0   France  Paris Saint-Germain       16      7
# 1                        135.0   Norway    Borussia Dortmund       10     13
# 2                        108.0  England    Tottenham Hotspur       16      7
# 3                         90.0  England      Manchester City       15      2
# 4                         90.0    Egypt         Liverpool FC       15     15
#
#    Own Goals  Assists  Yellow Cards  Second Yellow Cards  Red Cards  \
# 0          0       11             3                    0          0
# ...

# %%
df["Country"].nunique() # checking the unique "count" values for a particular column
# Out:
# 57

# %%
df["Country"].unique() # checking the column values which is having unique values
# Out:
# array(['France', 'Norway', 'England', 'Egypt', 'Belgium', 'Brazil',
#        'Netherlands', 'Portugal', 'Germany', 'Senegal', 'Korea, South',
#        'Spain', 'Argentina', 'Canada', 'Morocco', 'Italy', 'Serbia',
#        'Slovenia', 'Uruguay', 'Scotland', 'Nigeria', 'Slovakia', 'Poland',
#        "Cote d'Ivoire", 'Austria', 'United States', 'Turkey', 'Mexico',
#        'Croatia', 'Czech Republic', 'Algeria', 'Burkina Faso', 'Sweden',
#        'Ghana', 'Denmark', 'Jamaica', 'Colombia', 'Guinea', 'Switzerland',
#        'Ukraine', 'Russia', 'DR Congo', 'Hungary', 'Mali', 'Japan',
#        'Cameroon', 'Iran', 'Montenegro', 'Gabon', 'Albania', 'Zambia',
#        'The Gambia', 'Israel', 'Georgia', 'Venezuela', 'Wales', 'Peru'],
#       dtype=object)

# %%
df["Country"].value_counts() #checking the "count" of unique values for a particular column
# Out:
# England           67
# France            58
# Spain             52
# Brazil            41
# Germany           29
# Portugal          26
# Italy             26
# Argentina         22
# Netherlands       17
# Belgium           14
# Uruguay           11
# Cote d'Ivoire      8
# Croatia            8
# Denmark            7
# Nigeria            7
# Colombia           7
# Austria            6
# Turkey             6
# Senegal            6
# Switzerland        6
# Serbia             5
# Scotland           5
# Poland             5
# United States      5
# Sweden             4
# Algeria            4
# Morocco            4
# Mexico             3
# Norway             3
# Ukraine            3
# Zambia             2
# Albania            2
# Mali               2
# Guinea             2
# Japan              2
# Canada             2
# Czech Republic     2
# Burkina Faso       2
# The Gambia         1
# Iran               1
# Israel             1
# Georgia            1
# Gabon              1
# ...

# %%
df.nunique() #checking the unique value for all the columns
# Out:
# Unnamed: 0                     500
# Name                           500
# Position                        13
# Age                             20
# Markey Value In Millions(£)     34
# Country                         57
# Club                            81
# Matches                         24
# Goals                           17
# Own Goals                        2
# Assists                         12
# Yellow Cards                     8
# Second Yellow Cards              2
# Red Cards                        2
# Number Of Substitute In         14
# Number Of Substitute Out        18
# dtype: int64

# %%
df['Country'].value_counts().plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Data Cleaning**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Position', 'Age', 'Markey Value In Millions(£)',
#        'Country', 'Club', 'Matches', 'Goals', 'Own Goals', 'Assists',
#        'Yellow Cards', 'Second Yellow Cards', 'Red Cards',
#        'Number Of Substitute In', 'Number Of Substitute Out'],
#       dtype='object')

# %%
#let's remove the columns which are aperantly least important
df = df.drop(['Unnamed: 0','Age','Assists'], axis=1)

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Markey Value In Millions(£)', 'Country', 'Club',
#        'Matches', 'Goals', 'Own Goals', 'Yellow Cards', 'Second Yellow Cards',
#        'Red Cards', 'Number Of Substitute In', 'Number Of Substitute Out'],
#       dtype='object')

# %%
#Let us check the null value count in each column
df.isnull().sum()
# Out:
# Name                           0
# Position                       0
# Markey Value In Millions(£)    0
# Country                        0
# Club                           0
# Matches                        0
# Goals                          0
# Own Goals                      0
# Yellow Cards                   0
# Second Yellow Cards            0
# Red Cards                      0
# Number Of Substitute In        0
# Number Of Substitute Out       0
# dtype: int64
