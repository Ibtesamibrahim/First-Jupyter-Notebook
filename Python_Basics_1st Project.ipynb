# %% [markdown]
# ![what-is-python-programming.jpg](attachment:what-is-python-programming.jpg)

# %% [markdown]
# ![Python.png](attachment:Python.png)

# %% [markdown]
# What is Python?
#
# Python is a Popular programming language which is used to interact with the system. It is a high level langauge.

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
a= 5

# %%
a
# Out:
# 5

# %%
print(a)
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
num= "My name is Ibtesam Ibrahim"

# %%
print(num)
# Out:
# My name is Ibtesam Ibrahim

# %% [markdown]
# Working with Integers!!

# %%
4+3 #Addition
# Out:
# 7

# %%
7-5 #subtraction
# Out:
# 2

# %%
5*7 #multiplication
# Out:
# 35

# %%
40/5 #divide
# Out:
# 8.0

# %%
14%6 #mod (modulo) (remainder)
# Out:
# 2

# %% [markdown]
# #Presidence / Priority of operators:

# %%
5*8/4
# Out:
# 10.0

# %%
5*3*4
# Out:
# 60

# %%
5*(8+5)
# Out:
# 65

# %%
9/4*3
# Out:
# 6.75

# %%
5/2
# Out:
# 2.5

# %%
35//6
# Out:
# 5

# %%
#Thank You

# %% [markdown]
# ""FLOAT""

# %%
1.8+6.7
# Out:
# 8.5

# %%
1.5*2
# Out:
# 3.0

# %%
x= input()
# Out:
# 79

# %%
x
# Out:
# '79'

# %% [markdown]
# **COMPLEX NUMBER**

# %%
3+5j
# Out:
# (3+5j)

# %%
c=6+3j

# %%
c
# Out:
# (6+3j)

# %%
type(c)
# Out:
# complex

# %% [markdown]
# **Working with Complex Data Type**

# %%
3+5j + 6+3j
# Out:
# (9+8j)

# %%
p = 4+ 3j
q = 8+ 5j

p+q
# Out:
# (12+8j)

# %%
p * 3
# Out:
# (12+9j)

# %%
x = ()

# %%
6+7j
# Out:
# (6+7j)

# %% [markdown]
# **BOOLEANS**

# %%
a = True
b = False

# %%
a + b
# Out:
# 1

# %%
type (a+b)
# Out:
# int

# %%
b / a
# Out:
# 0.0

# %%
x = input()
# Out:
# 79

# %%
type(x)
# Out:
# str

# %% [markdown]
# **STRING**

# %%
a = "pqrs"

# %%
type(a)
# Out:
# str

# %%
a = '7'

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# '7'

# %%
p = "My name is Ibtesam"

# %%
p[0]
# Out:
# 'M'

# %%
p[13]
# Out:
# 't'

# %%
p[7]
# Out:
# ' '

# %%
p[8]
# Out:
# 'i'

# %%
p[-1]
# Out:
# 'm'

# %%
p[-4]
# Out:
# 'e'

# %%
p[-2]
# Out:
# 'a'

# %%
p[-8]
# Out:
# ' '

# %%
p[3:9]
# Out:
# 'name i'

# %%
p[0:5]
# Out:
# 'My na'

# %%
p[4:8]
# Out:
# 'ame '

# %%
p.upper()
# Out:
# 'MY NAME IS IBTESAM'

# %%
p.lower()
# Out:
# 'my name is ibtesam'

# %%
p.replace('Ibtesam','Ibrahim')
# Out:
# 'My name is Ibrahim'

# %%
q= "and his Name is Amit"

# %%
p + q #concatination
# Out:
# 'My name is Ibtesamand his Name is Amit'

# %%
p + ' ' + q
# Out:
# 'My name is Ibtesam and his Name is Amit'

# %%
x = input()
# Out:
# 85

# %%
type(x)
# Out:
# str

# %% [markdown]
# **LIST**

# %%
mylist = [20,30,40,60,30,20]

# %%
type(mylist)
# Out:
# list

# %%
list1 = [13,68,85, 'amit', 2,6, 3.455, 'rahul', [4,6,2], True]

# %%
type(list1)
# Out:
# list

# %%
x = list(input())
# Out:
# 8,6,"rahul"

# %%
type(x)
# Out:
# list

# %%
x
# Out:
# ['8', ',', '6', ',', '"', 'r', 'a', 'h', 'u', 'l', '"']

# %% [markdown]
# **Working with List**

# %%
list2 = ['ganpati', 'bappa', 'moriya', '64', [4,6,3], (7,'di')]

# %% [markdown]
# Indexing:

# %%
list2[0]
# Out:
# 'ganpati'

# %%
list2[4]
# Out:
# [4, 6, 3]

# %%
list2[-1]
# Out:
# (7, 'di')

# %%
list2[0][2] #nested indexing
# Out:
# 'n'

# %%
list2[4][2]
# Out:
# 3

# %%
list2[5][1]
# Out:
# 'di'

# %%
list2[-2][-1]
# Out:
# 3

# %% [markdown]
# **Slicing**

# %%
list2
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list2[0:3]
# Out:
# ['ganpati', 'bappa', 'moriya']

# %%
list2[-6:-1]
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3]]

# %%
list2[1:]
# Out:
# ['bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %% [markdown]
# **Other Functions**

# %%
list2
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list2.append("rahul") #add more value

# %%
list2
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di'), 'rahul']

# %%
list2.remove("rahul") #removing one value

# %%
list2
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list2.remove("bappa")

# %%
list2
# Out:
# ['ganpati', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list2.clear() #clearing the whole list

# %%
list2
# Out:
# []

# %%
list2 = ['ganpati', 'bappa', 'moriya', '64', [4,6,3], (7,'di')]

# %%
list3=list2 #copying list

# %%
list3
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list3= list2.copy()

# %%
list3
# Out:
# ['ganpati', 'bappa', 'moriya', '64', [4, 6, 3], (7, 'di')]

# %%
list4= [5,4,5,8,2,5,3,5,5,7]

# %%
list4.count(5) #counting the repeation of a value
# Out:
# 5

# %%
list4.insert(6,8) #inserting value at an exact index

# %%
list4
# Out:
# [5, 4, 5, 8, 2, 5, 8, 3, 5, 5, 7]

# %%
list4.reverse() #reversing the list

# %%
list4
# Out:
# [7, 5, 5, 3, 8, 5, 2, 8, 5, 4, 5]

# %%
list4.sort() #sorting the vslue of a list

# %%
list4
# Out:
# [2, 3, 4, 5, 5, 5, 5, 5, 7, 8, 8]

# %%
list4[3]="Ibtesam" #replacing a value at specific indix

# %%
list4
# Out:
# [2, 3, 4, 'Ibtesam', 5, 5, 5, 5, 7, 8, 8]

# %% [markdown]
# **Tuples**:

# %%
a= (8,6,5,'rahul','amit',43.9,[7,"no"],(2,4,0))

# %%
type(a)
# Out:
# tuple

# %%
b= input()
# Out:
# 86

# %%
type(b)
# Out:
# str

# %%
b= tuple(input())
# Out:
# 54

# %%
b
# Out:
# ('5', '4')

# %%
type(b)
# Out:
# tuple

# %% [markdown]
# working with Tuple:
#
# Exactly same as list *Difference B/W list and Tuple..
#
# List is not immutable (means, we can change the value of list after creation).
#
# Tuple is immutable (mease , we can not change the value of list after creation).

# %%
list5= [4,5,7,"up"]

# %%
list5[3]="down"

# %%
list5
# Out:
# [4, 5, 7, 'down']

# %%
tuple1=(4,5,8,7,6,2,"front")

# %%
tuple1[6]="back"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 tuple1[6]="back"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Hance proved!!!
#
# Features of Tuple:

# %%
tuple2=(5,4.2,6,'p',8,2.3,[0,'q'])

# %%
tuple2[6][1]='quality' #tuple support changing nested value

# %%
tuple2
# Out:
# (5, 4.2, 6, 'p', 8, 2.3, [0, 'quality'])

# %%
tuple3 = tuple1 + tuple2 #concatination of two tuples

# %%
tuple3
# Out:
# (4, 5, 8, 7, 6, 2, 'front', 5, 4.2, 6, 'p', 8, 2.3, [0, 'quality'])

# %%
del tuple3 #deleting a tuple completly

# %%
tuple3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 tuple3
#
# NameError: name 'tuple3' is not defined

# %%
tuple2
# Out:
# (5, 4.2, 6, 'p', 8, 2.3, [0, 'quality'])

# %%
'p' in tuple2 #
# Out:
# True

# %%
1 in tuple2
# Out:
# False

# %% [markdown]
# Chracteristics of "set" data type in python
#
# Unordered (you can't set the order, it will be automatically stored in ascending order.)
#
# It will always shows unique value.
#
# It does not have any index.

# %%
set1= {5,4,3,"iq",0,9.3}

# %%
type(set1)
# Out:
# set

# %%
set2= {4,5,3,4,6,4,'ram',5,8,'amit',0} #no duplicate values

# %%
set2
# Out:
# {0, 3, 4, 5, 6, 8, 'amit', 'ram'}

# %%
set3= {9,5,3,14,5,17,0} #unordred/ sorted

# %%
set3
# Out:
# {0, 3, 5, 9, 14, 17}

# %% [markdown]
# **Working with Set**:

# %%
'amit' in set2
# Out:
# True

# %%
set1.add("1+")

# %%
set1
# Out:
# {0, '1+', 3, 4, 5, 9.3, 'iq'}

# %%
set2.add(9)

# %%
set2
# Out:
# {0, 3, 4, 5, 6, 8, 9, 'amit', 'ram'}

# %%
set2.update(["rahul","imran","hersh","surya"]) #adding multiple value to a set

# %%
set2
# Out:
# {0, 3, 4, 5, 6, 8, 9, 'amit', 'hersh', 'imran', 'rahul', 'ram', 'surya'}

# %%
set1.clear() #clearing the whole set

# %%
set1
# Out:
# set()

# %% [markdown]
# **Thank You**
